# %% [markdown]
# ## Colab이란
# * 클라우드 기반의 주피터 노트북 개발환경
# * 로컬에 파이썬 환경 없이도 사용 가능
# * GPU 무료 사용 가능
# * 기본적으로 여러 최신 패키지가 내장되어 있음

# %%
# 드라이브 마운트 하기

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# 자주 사용할 패키지 version 확인

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# 현재 working directory
print(os.getcwd())

# pandas version
print(pd.__version__)

# numpy version
print(np.__version__)

# python version
print(sys.version)

# 다음과 같이도 확인가능

# !python --version
# Out:
# /content
# 1.3.5
# 1.21.5
# 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]
# Python 3.7.12

# %% [markdown]
# ### 구글 드라이브 사용

# %%
# 코드 작성하여 텍스트 파일로 변환 후 구글 드라이브에 저장 가능

path = '/gdrive/MyDrive/test.txt'

f=open(os.getcwd() + path,'w')
f.write("안녕하세요\n")
f.write("만나서 반갑습니다.")
f.close()

# %%
# 폴더 내에 있는 파일 로드하여 읽는 것도 가능함

f=open(os.getcwd() + path,'r')
data=f.read()
print(data)
f.close()
# Out:
# 안녕하세요
# 만나서 반갑습니다.

# %% [markdown]
# ### 기본 파이썬 입출력

# %%
# 입출력

name=input('이름을 입력하세요: ')

id=input('학번을 입력하세요: ')

print('제 이름은', name, '이며, 학번은', id, '입니다!')
# Out:
# 이름을 입력하세요: 유근태
# 학번을 입력하세요: 2018112462
# 제 이름은 유근태 이며, 학번은 2018112462 입니다!

# %%
# 출력 포맷팅 - % formatting

temp = 100

print('물은 %d 도에서 끓는다' % (temp))
# Out:
# 물은 100 도에서 끓는다

# %%
# 출력 포맷팅 - String formatting

age = 20

print('제 나이는 {} 입니다'.format(age))
# Out:
# 제 나이는 20 입니다

# %%
# 출력 포맷팅 - f-string
# 직관적이고 용이하다는 장점

pi = 3.14
r = 20

print(f'반지름이 {r}인 원의 둘레는 {2 * pi * r }')
# Out:
# 반지름이 20인 원의 둘레는 125.60000000000001

# %%
# 숫자 출력

print(f'반지름이 {r}인 원의 둘레는 {2 * pi * r:.2f}')
# Out:
# 반지름이 20인 원의 둘레는 125.60

# %% [markdown]
# ### 실습 1

# %%
# 본인의 학번, 이름, 나이를 f-string 방식을 이용하여 출력하세요

# %%
name = '유근태'
age = 23
id = 2018112462

print(f'제 이름은 {name}이며, 나이는 {age}입니다. 그리고 제 학번은 {id}입니다.')
# Out:
# 제 이름은 유근태이며, 나이는 23입니다. 그리고 제 학번은 2018112462입니다.

# %% [markdown]
# 파일명 **'머신러닝_실습_개요_학번_이름'**으로 **.ipynb** 파일 다운로드하여 이클래스에 제출해 주세요
